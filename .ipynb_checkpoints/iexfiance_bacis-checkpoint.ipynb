# %%
# %env IEX_TOKEN=sk_a9ccbee140454466bf7da631df08acc0
# Out:
# env: IEX_TOKEN=sk_a9ccbee140454466bf7da631df08acc0

# %%
from iexfinance.stocks import Stock
a = Stock("AAPL")
a.get_quote()
# Out:
#      avgTotalVolume calculationPrice change changePercent close closeSource  \
# AAPL       96313933             tops  -2.07      -0.01535  None    official
#
#      closeTime companyName delayedPrice delayedPriceTime  ... openTime  \
# AAPL      None   Apple Inc         None             None  ...     None
#
#      peRatio previousClose previousVolume                    primaryExchange  \
# AAPL   36.08        134.84       94264215  NASDAQ/NGS (GLOBAL SELECT MARKET)
#
#      symbol    volume week52High week52Low   ytdChange
# AAPL   AAPL  36660956     144.87     65.85 -0.00276056
#
# [1 rows x 55 columns]

# %%
from iexfinance.stocks import Stock

def get_stock_price(stock_name: str):
    stock = Stock(stock_name)
    return stock.get_price()

# %%
from datetime import datetime
from iexfinance.stocks import get_historical_data

start = datetime(2018, 4, 1)
end = datetime(2021, 4, 19)
df = get_historical_data("AAPL", start, end)

# %%
plt.figure(figsize=(10, 4))
plt.plot(df.index, df['open'])
plt.title('Daily Times Series for the apple');
plt.savefig('hlle.png')

# %%
ax = df.plot()

# %%
fig = ax.get_figure()

# %%
fig.savefig('asdf.png')

# %%
df = get_historical_data("TSLA", "20210419", close_only=True)

# %%
df
# Out:
#              close    volume
# 2021-04-19  714.63  39686226

# %%
df = get_historical_data("TSLA", start, end, output_format='pandas')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3a8818c2ce5d> in <module>
# ----> 1 df = get_historical_data("TSLA", start, end, output_format='pandas')
#
# NameError: name 'get_historical_data' is not defined

# %%
df
# Out:
#              close    high      low    open symbol    volume  \
# 2021-04-01  661.75  692.42   659.42  688.37   TSLA  35298378
# 2021-04-05  691.05  708.16    684.7  707.71   TSLA  41842767
# 2021-04-06  691.62  696.55   681.37   690.3   TSLA  28271839
# 2021-04-07  670.97  691.38   667.84     687   TSLA  26309433
# 2021-04-08   683.8  689.55  671.645  677.38   TSLA  23924329
# 2021-04-09  677.02  680.97   669.43  677.77   TSLA  21437087
# 2021-04-12  701.98   704.8   682.09   685.7   TSLA  29135670
# 2021-04-13  762.32     763   710.66   712.7   TSLA  44652808
# 2021-04-14  732.23  780.79   728.03   770.7   TSLA  49017434
# 2021-04-15  738.85  743.69   721.31   743.1   TSLA  27848900
# 2021-04-16  739.78  749.41    724.6  728.65   TSLA  27979526
# 2021-04-19  714.63   725.4    691.8   719.6   TSLA  39686226
#
#                            id   key subkey        updated  ...     uLow  \
# 2021-04-01  HISTORICAL_PRICES  TSLA         1617324505000  ...   659.42
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
from iexfinance.stocks import Stock

aapl = Stock("AAPL")
aapl.get_balance_sheet()
# Out:
#            accountsPayable capitalSurplus  commonStock currency currentAssets  \
# 2021-01-28     63846000000           None  16935119000      USD  154106000000
#
#             currentCash currentLongTermDebt filingType  fiscalDate  \
# 2021-01-28  76826000000         12762000000       10-Q  2020-12-26
#
#            fiscalQuarter  ... symbol   totalAssets totalCurrentLiabilities  \
# 2021-01-28             1  ...   AAPL  354054000000            132507000000
#
#            totalLiabilities treasuryStock             id   key     subkey  \
# 2021-01-28     287830000000             0  BALANCE_SHEET  AAPL  quarterly
#
#                      date        updated
# 2021-01-28  1608940800000  1612292383000
#
# [1 rows x 38 columns]

# %%
aapl.get_income_statement()
# Out:
#            costOfRevenue currency         ebit filingType  fiscalDate  \
# 2021-01-28   67111000000      USD  33534000000       10-Q  2020-12-26
#
#            fiscalQuarter fiscalYear  grossProfit   incomeTax interestIncome  \
# 2021-01-28             1       2021  44328000000  4824000000      638000000
#
#             ...  reportDate researchAndDevelopment sellingGeneralAndAdmin  \
# 2021-01-28  ...  2021-01-28             5163000000             5631000000
#
#            symbol  totalRevenue      id   key     subkey           date  \
# 2021-01-28   AAPL  111439000000  INCOME  AAPL  quarterly  1608940800000
#
#                   updated
# 2021-01-28  1612292383000
#
# [1 rows x 27 columns]

# %%
aapl.get_cash_flow()
# Out:
#            capitalExpenditures    cashChange     cashFlow cashFlowFinancing  \
# 2021-01-28         -3500000000  -14117000000  38763000000      -32249000000
#
#            changesInInventories changesInReceivables currency depreciation  \
# 2021-01-28            912000000          21175000000      USD   2666000000
#
#            dividendsPaid exchangeRateEffect  ...    netIncome  \
# 2021-01-28          None               None  ...  28755000000
#
#            otherFinancingCashFlows  reportDate symbol totalInvestingCashFlows  \
# 2021-01-28                    None  2021-01-28   AAPL             -8584000000
#
#                    id   key     subkey           date        updated
# 2021-01-28  CASH_FLOW  AAPL  quarterly  1608940800000  1612292383000
#
# [1 rows x 27 columns]
